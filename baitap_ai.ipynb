# %% [markdown]
# <a href="https://colab.research.google.com/github/nguyenduychinh/AI_24_02_23/blob/main/baitap_ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from skfuzzy.control.controlsystem import ControlSystemSimulation
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt
from skfuzzy import control as ctrl
temp= ctrl.Antecedent(np.arange(20.4,41.2,0.1),'Temp')
wind = ctrl.Antecedent(np.arange(0.7,3.1,0.1),'Wind')
flow = ctrl.Consequent(np.arange(0.2,9.1,0.1),'Flow')

temp['ratthap']=fuzz.trimf(temp.universe,[20.4,20.4,26])
temp['thap']=fuzz.trimf(temp.universe,[20.4,26,30])
temp['binhthuong']=fuzz.trimf(temp.universe,[26,30,37])
temp['cao']=fuzz.trimf(temp.universe,[30,37.2,41.2])
temp['ratcao']=fuzz.trimf(temp.universe,[37,41.2,41.2])
wind['ratnhe']=fuzz.trimf(wind.universe,[0.7,0.7,1.3])
wind['nhe']=fuzz.trimf(wind.universe,[0.7,1.3,2])
wind['binhthuong']=fuzz.trimf(wind.universe,[1.3,2,2.6])
wind['manh']=fuzz.trimf(wind.universe,[2,2.6,3.1])
wind['ratmanh']=fuzz.trimf(wind.universe,[2.6,3.1,3.1])
flow['VL']=fuzz.trimf(flow.universe,[0.2,0.2,2.8])
flow['L']=fuzz.trimf(flow.universe,[0.2,2.8,5])
flow['N']=fuzz.trimf(flow.universe,[2.8,5,7])
flow['H']=fuzz.trimf(flow.universe,[5,7,9.1])
flow['VH']=fuzz.trimf(flow.universe,[7,9.1,9.1])

luat1 = ctrl.Rule(temp['ratthap'] & wind['ratnhe'],flow['VL'])
luat2 = ctrl.Rule(temp['ratthap'] & wind['nhe'],flow['VL'])
luat3 = ctrl.Rule(temp['ratthap'] & wind['binhthuong'],flow['VL'])
luat4 = ctrl.Rule(temp['ratthap'] & wind['manh'],flow['L'])
luat5 = ctrl.Rule(temp['ratthap'] & wind['ratmanh'],flow['L'])
luat6 = ctrl.Rule(temp['thap'] & wind['ratnhe'],flow['VL'])
luat7 = ctrl.Rule(temp['thap'] & wind['nhe'],flow['VL'])
luat8 = ctrl.Rule(temp['thap'] & wind['binhthuong'],flow['VL'])
luat9 = ctrl.Rule(temp['thap'] & wind['manh'],flow['L'])
luat10 = ctrl.Rule(temp['thap'] & wind['ratmanh'],flow['N'])
luat11 = ctrl.Rule(temp['binhthuong'] & wind['ratnhe'],flow['L'])
luat12 = ctrl.Rule(temp['binhthuong'] & wind['nhe'],flow['L'])
luat13 = ctrl.Rule(temp['binhthuong'] & wind['binhthuong'],flow['L'])
luat14 = ctrl.Rule(temp['binhthuong'] & wind['manh'],flow['N'])
luat15 = ctrl.Rule(temp['binhthuong'] & wind['ratmanh'],flow['H'])
luat16 = ctrl.Rule(temp['cao'] & wind['ratnhe'],flow['L'])
luat17 = ctrl.Rule(temp['cao'] & wind['nhe'],flow['N'])
luat18 = ctrl.Rule(temp['cao'] & wind['binhthuong'],flow['N'])
luat19 = ctrl.Rule(temp['cao'] & wind['manh'],flow['H'])
luat20 = ctrl.Rule(temp['cao'] & wind['ratmanh'],flow['VH'])
luat21 = ctrl.Rule(temp['ratcao'] & wind['ratnhe'],flow['N'])
luat22 = ctrl.Rule(temp['ratcao'] & wind['nhe'],flow['N'])
luat23 = ctrl.Rule(temp['ratcao'] & wind['binhthuong'],flow['H'])
luat24 = ctrl.Rule(temp['ratcao'] & wind['manh'],flow['VH'])
luat25 = ctrl.Rule(temp['ratcao'] & wind['ratmanh'],flow['VH'])

tipping_ctrl = ctrl.ControlSystem([luat1,luat2,luat3,luat4,luat5,luat6,luat7,luat8,luat9,luat10,luat11,luat12,luat13,luat14,luat15,luat16,luat17,luat18,luat19,luat20,luat21,luat22,luat23,luat24,luat25])
tipping = ControlSystemSimulation(tipping_ctrl)
tipping.input['Temp']=38
tipping.input['Wind']=3
tipping.compute()
print(tipping.output['Flow'])
flow.view(sim = tipping)
# Out:
# 7.679800987901785

# %%
pip install scikit-fuzzy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 994.0/994.0 KB 10.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for scikit-fuzzy: filename=scikit_fuzzy-0.4.2-py3-none-any.whl size=894088 sha256=ddf9ba2b889de2ad5c537c019884b831c63b8974489e4018c9185775dd0b3b66
#   Stored in directory: /root/.cache/pip/wheels/2c/04/80/7eefb1a2de7d36aefd06432fab2a1486caf0a0596a7067391a
# Successfully built scikit-fuzzy
# ...

# %%
from skfuzzy.control.controlsystem import ControlSystemSimulation
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt
from skfuzzy import control as ctrl
huongvi= ctrl.Antecedent(np.arange(0,2,0.1),'Huongvi')
ngansach = ctrl.Antecedent(np.arange(0,2,0.1),'Ngansach')
vitri = ctrl.Antecedent(np.arange(0,2,0.1),'Vitri')
danhgia = ctrl.Antecedent(np.arange(0,2,0.1),'Danhgia')
moitruong = ctrl.Antecedent(np.arange(0,2,0.1),'Moitruong')
uathich = ctrl.Consequent(np.arange(2,10,0.1),'Uathich')

huongvi['thap']=fuzz.trimf(huongvi.universe,[0,0,1])
huongvi['binhthuong']=fuzz.trimf(huongvi.universe,[0,1,2])
huongvi['cao']=fuzz.trimf(huongvi.universe,[1,2,2])
ngansach['thap']=fuzz.trimf(ngansach.universe,[0,0,1])
ngansach['binhthuong']=fuzz.trimf(ngansach.universe,[0,1,2])
ngansach['cao']=fuzz.trimf(ngansach.universe,[1,2,2])
vitri['thap']=fuzz.trimf(vitri.universe,[0,0,1])
vitri['binhthuong']=fuzz.trimf(vitri.universe,[0,1,2])
vitri['cao']=fuzz.trimf(vitri.universe,[1,2,2])
danhgia['thap']=fuzz.trimf(danhgia.universe,[0,0,1])
danhgia['binhthuong']=fuzz.trimf(danhgia.universe,[0,1,2])
danhgia['cao']=fuzz.trimf(danhgia.universe,[1,2,2])
moitruong['thap']=fuzz.trimf(moitruong.universe,[0,0,1])
moitruong['binhthuong']=fuzz.trimf(moitruong.universe,[0,1,2])
moitruong['cao']=fuzz.trimf(moitruong.universe,[1,2,2])
uathich['cap1']=fuzz.trimf(uathich.universe,[2,2,4])
uathich['cap2']=fuzz.trimf(uathich.universe,[2,4,6])
uathich['cap3']=fuzz.trimf(uathich.universe,[4,6,8])
uathich['cap4']=fuzz.trimf(uathich.universe,[6,8,10])
uathich['cap5']=fuzz.trimf(uathich.universe,[8,10,10])

luat1 = ctrl.Rule(huongvi['thap'] & ngansach['thap']& vitri['thap']& danhgia['binhthuong']& moitruong['binhthuong'],uathich['cap1'])
luat2 = ctrl.Rule(huongvi['thap'] & ngansach['thap']& vitri['cao']& danhgia['binhthuong']& moitruong['binhthuong'],uathich['cap2'])
luat3 = ctrl.Rule(huongvi['thap'] & ngansach['cao']& vitri['thap']& danhgia['binhthuong']& moitruong['binhthuong'],uathich['cap2'])
luat4 = ctrl.Rule(huongvi['cao'] & ngansach['thap']& vitri['thap']& danhgia['binhthuong']& moitruong['binhthuong'],uathich['cap2'])
luat5 = ctrl.Rule(huongvi['binhthuong'] & ngansach['binhthuong']& vitri['thap']& danhgia['binhthuong']& moitruong['binhthuong'],uathich['cap2'])
luat6 = ctrl.Rule(huongvi['binhthuong'] & ngansach['thap']& vitri['binhthuong']& danhgia['binhthuong']& moitruong['binhthuong'],uathich['cap2'])
luat7 = ctrl.Rule(huongvi['thap'] & ngansach['binhthuong']& vitri['binhthuong']& danhgia['binhthuong']& moitruong['binhthuong'],uathich['cap2'])
luat8 = ctrl.Rule(huongvi['thap'] & ngansach['thap']& vitri['binhthuong']& danhgia['thap']& moitruong['binhthuong'],uathich['cap1'])
luat9 = ctrl.Rule(huongvi['thap'] & ngansach['binhthuong']& vitri['thap']& danhgia['thap']& moitruong['binhthuong'],uathich['cap1'])
luat10 = ctrl.Rule(huongvi['binhthuong'] & ngansach['thap']& vitri['thap']& danhgia['thap']& moitruong['binhthuong'],uathich['cap1'])
luat11 = ctrl.Rule(huongvi['cao'] & ngansach['thap']& vitri['binhthuong']& danhgia['binhthuong']& moitruong['binhthuong'],uathich['cap3'])
luat12 = ctrl.Rule(huongvi['cao'] & ngansach['binhthuong']& vitri['thap']& danhgia['binhthuong']& moitruong['binhthuong'],uathich['cap3'])
luat13 = ctrl.Rule(huongvi['binhthuong'] & ngansach['cao']& vitri['thap']& danhgia['binhthuong']& moitruong['binhthuong'],uathich['cap3'])
luat14 = ctrl.Rule(huongvi['thap'] & ngansach['cao']& vitri['binhthuong']& danhgia['binhthuong']& moitruong['binhthuong'],uathich['cap3'])
luat15 = ctrl.Rule(huongvi['thap'] & ngansach['binhthuong']& vitri['cao']& danhgia['binhthuong']& moitruong['binhthuong'],uathich['cap3'])
luat16 = ctrl.Rule(huongvi['binhthuong'] & ngansach['thap']& vitri['cao']& danhgia['binhthuong']& moitruong['binhthuong'],uathich['cap3'])
luat17 = ctrl.Rule(huongvi['thap'] & ngansach['cao']& vitri['cao']& danhgia['binhthuong']& moitruong['binhthuong'],uathich['cap3'])
luat18 = ctrl.Rule(huongvi['cao'] & ngansach['cao']& vitri['thap']& danhgia['binhthuong']& moitruong['binhthuong'],uathich['cap3'])
luat19 = ctrl.Rule(huongvi['cao'] & ngansach['cao']& vitri['binhthuong']& danhgia['binhthuong']& moitruong['cao'],uathich['cap4'])
luat20 = ctrl.Rule(huongvi['cao'] & ngansach['cao']& vitri['binhthuong']& danhgia['cao']& moitruong['binhthuong'],uathich['cap4'])
luat21 = ctrl.Rule(huongvi['binhthuong'] & ngansach['binhthuong']& vitri['cao']& danhgia['cao']& moitruong['cao'],uathich['cap4'])
luat22 = ctrl.Rule(huongvi['binhthuong'] & ngansach['cao']& vitri['cao']& danhgia['cao']& moitruong['binhthuong'],uathich['cap4'])
luat23 = ctrl.Rule(huongvi['cao'] & ngansach['cao']& vitri['cao']& danhgia['binhthuong']& moitruong['binhthuong'],uathich['cap4'])
luat24= ctrl.Rule(huongvi['cao'] & ngansach['cao']& vitri['cao']& danhgia['cao']& moitruong['thap'],uathich['cap4'])
luat25= ctrl.Rule(huongvi['cao'] & ngansach['cao']& vitri['cao']& danhgia['thap']& moitruong['cao'],uathich['cap4'])
luat26= ctrl.Rule(huongvi['cao'] & ngansach['cao']& vitri['thap']& danhgia['cao']& moitruong['cao'],uathich['cap4'])
luat27= ctrl.Rule(huongvi['cao'] & ngansach['thap']& vitri['cao']& danhgia['cao']& moitruong['cao'],uathich['cap4'])
luat28= ctrl.Rule(huongvi['thap'] & ngansach['cao']& vitri['cao']& danhgia['cao']& moitruong['cao'],uathich['cap4'])
luat29= ctrl.Rule(huongvi['binhthuong'] & ngansach['cao']& vitri['cao']& danhgia['cao']& moitruong['cao'],uathich['cap5'])
luat30= ctrl.Rule(huongvi['cao'] & ngansach['binhthuong']& vitri['cao']& danhgia['cao']& moitruong['cao'],uathich['cap5'])
luat31= ctrl.Rule(huongvi['cao'] & ngansach['cao']& vitri['binhthuong']& danhgia['cao']& moitruong['cao'],uathich['cap5'])
luat32= ctrl.Rule(huongvi['cao'] & ngansach['cao']& vitri['cao']& danhgia['binhthuong']& moitruong['cao'],uathich['cap5'])
luat33= ctrl.Rule(huongvi['cao'] & ngansach['cao']& vitri['cao']& danhgia['cao']& moitruong['binhthuong'],uathich['cap5'])
luat34= ctrl.Rule(huongvi['cao'] & ngansach['cao']& vitri['cao']& danhgia['cao']& moitruong['cao'],uathich['cap5'])
luat35= ctrl.Rule(huongvi['thap'] & ngansach['thap']& vitri['binhthuong']& danhgia['binhthuong']& moitruong['thap'],uathich['cap1'])
luat36= ctrl.Rule(huongvi['thap'] & ngansach['thap']& vitri['thap']& danhgia['binhthuong']& moitruong['cao'],uathich['cap1'])
luat37= ctrl.Rule(huongvi['cao'] & ngansach['thap']& vitri['thap']& danhgia['binhthuong']& moitruong['thap'],uathich['cap1'])
luat38= ctrl.Rule(huongvi['thap'] & ngansach['cao']& vitri['thap']& danhgia['binhthuong']& moitruong['thap'],uathich['cap1'])
luat39= ctrl.Rule(huongvi['thap'] & ngansach['thap']& vitri['cao']& danhgia['binhthuong']& moitruong['thap'],uathich['cap1'])
luat40= ctrl.Rule(huongvi['thap'] & ngansach['thap']& vitri['thap']& danhgia['cao']& moitruong['thap'],uathich['cap1'])


tipping_ctrl = ctrl.ControlSystem([luat1,luat2,luat3,luat4,luat5,luat6,luat7,luat8,luat9,luat10,luat11,luat12,luat13,luat14,luat15,luat16,luat17,luat18,luat19,luat20,luat21,luat22,luat23,luat24,luat25,luat26,luat27,luat28,luat29,luat30,luat31,luat32,luat33,luat34,luat35,luat36,luat37,luat38,luat39,luat40])
tipping = ControlSystemSimulation(tipping_ctrl)
tipping.input['Huongvi']=2.3
tipping.input['Ngansach']=2
tipping.input['Vitri']=2
tipping.input['Danhgia']=22
tipping.input['Moitruong']=0
tipping.compute()
print(tipping.output['Uathich'])
uathich.view(sim = tipping)
# Out:
# 7.99755583649389
