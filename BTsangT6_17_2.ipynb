# %% [markdown]
# <a href="https://colab.research.google.com/github/nguyenduychinh/AI_24_02_23/blob/main/BTsangT6_17_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
dataframe=pd.DataFrame()
dataframe['Name']=['Lemon','Apple', 'Banana']
dataframe['Price']=[5,6,7]
dataframe['License']=[ False, True, True]
dataframe
# Out:
#      Name  Price  License
# 0   Lemon      5    False
# 1   Apple      6     True
# 2  Banana      7     True

# %%
dataframe.shape
# Out:
# (3, 3)

# %%
df  = dataframe.info()
df = dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     3 non-null      object
#  1   Price    3 non-null      int64
#  2   License  3 non-null      bool
# dtypes: bool(1), int64(1), object(1)
# memory usage: 179.0+ bytes

# %%
list(df.columns)
# Out:
# ['Name', 'Price', 'License']

# %%
df.describe()
# Out:
#        Price
# count    3.0
# mean     6.0
# std      1.0
# min      5.0
# 25%      5.5
# 50%      6.0
# 75%      6.5
# max      7.0

# %%
df.loc[(df.Price==5)]
# Out:
#     Name  Price  License
# 0  Lemon      5    False

# %%
df.loc[(df.Price == 5)|(df.Name == 'Banana')]
# Out:
#      Name  Price  License
# 0   Lemon      5    False
# 2  Banana      7     True

# %%
df.loc[(df.Price ==5)|(df.Name == 'Banana'),['Name', 'Price']]
# Out:
#      Name  Price
# 0   Lemon      5
# 2  Banana      7

# %%
df.iloc[2]
type(df.iloc[2])
# Out:
# pandas.core.series.Series

# %%
df.iloc[[2]]
# Out:
#      Name  Price  License
# 2  Banana      7     True

# %%
df.iloc[0:2]
# Out:
#     Name  Price  License
# 0  Lemon      5    False
# 1  Apple      6     True

# %%
df.iloc[0:2,0:1]
# Out:
#     Name
# 0  Lemon
# 1  Apple

# %%
df.iloc[0:2,-1]
# Out:
# 0    False
# 1     True
# Name: License, dtype: bool

# %%
sum = df.Price.sum()
print(sum)
# Out:
# 18

# %%
max = df.Price.max()
print(max)
# Out:
# 7

# %%
count=df.Price.count()
print(count)
# Out:
# 3

# %%
new = pd.Series(['Orange', 10, True],index=['Name','Price','License'])
df.append(new, ignore_index=True)
# Out:
#      Name  Price  License
# 0   Lemon      5    False
# 1   Apple      6     True
# 2  Banana      7     True
# 3  Orange     10     True

# %%
df['Location'] = ['USA','VN','Cam']
df
# Out:
#      Name  Price  License Location
# 0   Lemon      5    False      USA
# 1   Apple      6     True       VN
# 2  Banana      7     True      Cam

# %%
dataframe.drop(1, axis=0).head(10)
# Out:
#      Name  Price  License Location
# 0   Lemon      5    False      USA
# 2  Banana      7     True      Cam

# %%
df.drop('Location',axis=1).head()
# Out:
#      Name  Price  License
# 0   Lemon      5    False
# 1   Apple      6     True
# 2  Banana      7     True

# %%
#replace
df['Price'].replace(5,7).head(5)
# Out:
# 0    7
# 1    6
# 2    7
# Name: Price, dtype: int64

# %%
#rename columns
df.rename(columns={'Price':'Cost'}).head()
# Out:
#      Name  Cost  License Location
# 0   Lemon     5    False      USA
# 1   Apple     6     True       VN
# 2  Banana     7     True      Cam

# %%
# 2. NOWKING DATA

# %%
import pandas as pd
url='/medals.csv'
dataframe=pd.read_csv(url)
dataframe.head()
# Out:
#    Year      City       Sport      Discipline  NOC       Event Event gender  \
# 0  1924  Chamonix     Skating  Figure skating  AUT  individual            M
# 1  1924  Chamonix     Skating  Figure skating  AUT  individual            W
# 2  1924  Chamonix     Skating  Figure skating  AUT       pairs            X
# 3  1924  Chamonix   Bobsleigh       Bobsleigh  BEL    four-man            M
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN  ice hockey            M
#
#     Medal
# 0  Silver
# 1    Gold
# 2    Gold
# 3  Bronze
# 4    Gold

# %%
data=dataframe
data.shape
# Out:
# (2311, 8)

# %%
data.describe()
# Out:
#               Year
# count  2311.000000
# mean   1980.361748
# std      22.089091
# min    1924.000000
# 25%    1968.000000
# 50%    1988.000000
# 75%    1998.000000
# max    2006.000000

# %%
count=data.Medal.count()
print(count)
# Out:
# 2311

# %%
data.loc[(data.Medal== 'Gold')].head(10)
# Out:
#     Year      City       Sport       Discipline  NOC                Event  \
# 1   1924  Chamonix     Skating   Figure skating  AUT           individual
# 2   1924  Chamonix     Skating   Figure skating  AUT                pairs
# 4   1924  Chamonix  Ice Hockey       Ice Hockey  CAN           ice hockey
# 7   1924  Chamonix     Skating    Speed skating  FIN               10000m
# 9   1924  Chamonix     Skating    Speed skating  FIN                1500m
# 10  1924  Chamonix     Skating    Speed skating  FIN                5000m
# 14  1924  Chamonix     Skating    Speed skating  FIN  combined (4 events)
# 20  1924  Chamonix     Curling          Curling  GBR              curling
# 30  1924  Chamonix      Skiing  Cross Country S  NOR                 18km
# 33  1924  Chamonix      Skiing  Cross Country S  NOR                 50km
#
#    Event gender Medal
# 1             W  Gold
# 2             X  Gold
# 4             M  Gold
# 7             M  Gold
# 9             M  Gold
# ...

# %%
data= data.set_index(data['NOC'])
data.loc['GER']
# Out:
#      Year                    City       Sport       Discipline  NOC  \
# NOC
# GER  1928              St. Moritz   Bobsleigh        Bobsleigh  GER
# GER  1932             Lake Placid   Bobsleigh        Bobsleigh  GER
# GER  1932             Lake Placid  Ice Hockey       Ice Hockey  GER
# GER  1936  Garmisch-Partenkirchen     Skating   Figure skating  GER
# GER  1936  Garmisch-Partenkirchen     Skating   Figure skating  GER
# ..    ...                     ...         ...              ...  ...
# GER  2006                   Turin      Skiing  Cross Country S  GER
# GER  2006                   Turin      Skiing  Nordic Combined  GER
# GER  2006                   Turin      Skiing  Nordic Combined  GER
# GER  2006                   Turin      Skiing  Nordic Combined  GER
# GER  2006                   Turin      Skiing        Snowboard  GER
#
#                      Event Event gender   Medal
# NOC
# GER               five-man            M  Bronze
# ...

# %%
data.count()
# Out:
# Year            2311
# City            2311
# Sport           2311
# Discipline      2311
# NOC             2311
# Event           2311
# Event gender    2311
# Medal           2311
# dtype: int64

# %%
data['NOC'].count()
# Out:
# 2311

# %%
data.iloc[0:10] # ~[:10]
# Out:
#      Year      City       Sport      Discipline  NOC            Event  \
# NOC
# AUT  1924  Chamonix     Skating  Figure skating  AUT       individual
# AUT  1924  Chamonix     Skating  Figure skating  AUT       individual
# AUT  1924  Chamonix     Skating  Figure skating  AUT            pairs
# BEL  1924  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# CAN  1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# FIN  1924  Chamonix    Biathlon        Biathlon  FIN  military patrol
# FIN  1924  Chamonix     Skating  Figure skating  FIN            pairs
# FIN  1924  Chamonix     Skating   Speed skating  FIN           10000m
# FIN  1924  Chamonix     Skating   Speed skating  FIN           10000m
# FIN  1924  Chamonix     Skating   Speed skating  FIN            1500m
#
#     Event gender   Medal
# NOC
# AUT            M  Silver
# AUT            W    Gold
# AUT            X    Gold
# BEL            M  Bronze
# CAN            M    Gold
# FIN            M  Silver
# ...

# %%
data.iloc[[200,]]
# Out:
#      Year        City   Sport       Discipline  NOC       Event Event gender  \
# NOC
# FIN  1948  St. Moritz  Skiing  Nordic Combined  FIN  individual            M
#
#     Medal
# NOC
# FIN  Gold

# %%
data.loc['USA']
# Out:
#      Year        City       Sport      Discipline  NOC                 Event  \
# NOC
# USA  1924    Chamonix  Ice Hockey      Ice Hockey  USA            ice hockey
# USA  1924    Chamonix     Skating  Figure skating  USA            individual
# USA  1924    Chamonix     Skating   Speed skating  USA                  500m
# USA  1924    Chamonix      Skiing     Ski Jumping  USA  K90 individual (70m)
# USA  1928  St. Moritz   Bobsleigh       Bobsleigh  USA              five-man
# ..    ...         ...         ...             ...  ...                   ...
# USA  2006       Turin      Skiing       Snowboard  USA             Half-pipe
# USA  2006       Turin      Skiing       Snowboard  USA             Half-pipe
# USA  2006       Turin      Skiing       Snowboard  USA             Half-pipe
# USA  2006       Turin      Skiing       Snowboard  USA       Snowboard Cross
# USA  2006       Turin      Skiing       Snowboard  USA       Snowboard Cross
#
#     Event gender   Medal
# NOC
# ...

# %%
data[data['NOC']=='CAN'].head(10)
# Out:
#      Year                    City       Sport      Discipline  NOC  \
# NOC
# CAN  1924                Chamonix  Ice Hockey      Ice Hockey  CAN
# CAN  1928              St. Moritz  Ice Hockey      Ice Hockey  CAN
# CAN  1932             Lake Placid  Ice Hockey      Ice Hockey  CAN
# CAN  1932             Lake Placid     Skating  Figure skating  CAN
# CAN  1932             Lake Placid     Skating   Speed skating  CAN
# CAN  1932             Lake Placid     Skating   Speed skating  CAN
# CAN  1932             Lake Placid     Skating   Speed skating  CAN
# CAN  1932             Lake Placid     Skating   Speed skating  CAN
# CAN  1932             Lake Placid     Skating   Speed skating  CAN
# CAN  1936  Garmisch-Partenkirchen  Ice Hockey      Ice Hockey  CAN
#
#           Event Event gender   Medal
# NOC
# CAN  ice hockey            M    Gold
# CAN  ice hockey            M    Gold
# CAN  ice hockey            M    Gold
# CAN  individual            M  Bronze
# ...

# %%
data[(data['Year']>=1990)&(data['Year']<=2006) & (data['NOC']=='USA')&(data['Event gender']=='W')&(data['Medal']=='Gold')].head(10)
# Out:
#      Year         City       Sport      Discipline  NOC       Event  \
# NOC
# USA  1992  Albertville     Skating  Figure skating  USA  individual
# USA  1992  Albertville     Skating  Short Track S.  USA        500m
# USA  1992  Albertville     Skating   Speed skating  USA       1000m
# USA  1992  Albertville     Skating   Speed skating  USA        500m
# USA  1992  Albertville      Skiing  Freestyle Ski.  USA      moguls
# USA  1994  Lillehammer     Skating  Short Track S.  USA        500m
# USA  1994  Lillehammer     Skating   Speed skating  USA       1000m
# USA  1994  Lillehammer     Skating   Speed skating  USA        500m
# USA  1994  Lillehammer      Skiing   Alpine Skiing  USA     super-G
# USA  1998       Nagano  Ice Hockey      Ice Hockey  USA  ice hockey
#
#     Event gender Medal
# NOC
# USA            W  Gold
# USA            W  Gold
# USA            W  Gold
# USA            W  Gold
# USA            W  Gold
# USA            W  Gold
# USA            W  Gold
# ...

# %%
data['NOC'].value_counts()
# Out:
# NOR    280
# USA    216
# URS    194
# AUT    185
# GER    158
# FIN    151
# CAN    119
# SUI    118
# SWE    118
# GDR    110
# ITA    101
# FRA     83
# NED     78
# RUS     76
# FRG     41
# CHN     33
# JPN     32
# KOR     31
# TCH     25
# EUN     23
# GBR     21
# EUA     19
# CZE     10
# LIE      9
# POL      8
# CRO      7
# BUL      6
# EST      6
# AUS      6
# BLR      6
# HUN      6
# UKR      5
# BEL      5
# KAZ      5
# YUG      4
# SLO      4
# ESP      2
# PRK      2
# LUX      2
# LAT      1
# ROU      1
# DEN      1
# UZB      1
# NZL      1
# SVK      1
# Name: NOC, dtype: int64

# %%
data['NOC'].unique()
# Out:
# array(['AUT', 'BEL', 'CAN', 'FIN', 'FRA', 'GBR', 'NOR', 'SUI', 'SWE',
#        'USA', 'GER', 'TCH', 'HUN', 'ITA', 'FRG', 'NED', 'EUA', 'JPN',
#        'POL', 'URS', 'PRK', 'GDR', 'ROU', 'ESP', 'LIE', 'BUL', 'YUG',
#        'CHN', 'EUN', 'KOR', 'LUX', 'NZL', 'AUS', 'BLR', 'KAZ', 'RUS',
#        'SLO', 'UKR', 'UZB', 'CZE', 'DEN', 'CRO', 'EST', 'LAT', 'SVK'],
#       dtype=object)

# %%
data.drop('NOC', axis=1).head(10)
# Out:
#      Year      City       Sport      Discipline            Event Event gender  \
# NOC
# AUT  1924  Chamonix     Skating  Figure skating       individual            M
# AUT  1924  Chamonix     Skating  Figure skating       individual            W
# AUT  1924  Chamonix     Skating  Figure skating            pairs            X
# BEL  1924  Chamonix   Bobsleigh       Bobsleigh         four-man            M
# CAN  1924  Chamonix  Ice Hockey      Ice Hockey       ice hockey            M
# FIN  1924  Chamonix    Biathlon        Biathlon  military patrol            M
# FIN  1924  Chamonix     Skating  Figure skating            pairs            X
# FIN  1924  Chamonix     Skating   Speed skating           10000m            M
# FIN  1924  Chamonix     Skating   Speed skating           10000m            M
# FIN  1924  Chamonix     Skating   Speed skating            1500m            M
#
#       Medal
# NOC
# AUT  Silver
# AUT    Gold
# AUT    Gold
# BEL  Bronze
# CAN    Gold
# FIN  Silver
# ...

# %%
data.drop(data.columns[2:4], axis=1).head(10)
# Out:
#      Year      City  NOC            Event Event gender   Medal
# NOC
# AUT  1924  Chamonix  AUT       individual            M  Silver
# AUT  1924  Chamonix  AUT       individual            W    Gold
# AUT  1924  Chamonix  AUT            pairs            X    Gold
# BEL  1924  Chamonix  BEL         four-man            M  Bronze
# CAN  1924  Chamonix  CAN       ice hockey            M    Gold
# FIN  1924  Chamonix  FIN  military patrol            M  Silver
# FIN  1924  Chamonix  FIN            pairs            X  Silver
# FIN  1924  Chamonix  FIN           10000m            M    Gold
# FIN  1924  Chamonix  FIN           10000m            M  Silver
# FIN  1924  Chamonix  FIN            1500m            M    Gold

# %%
data[data['NOC']!='CAN'].head(10)
# Out:
#      Year      City      Sport      Discipline  NOC            Event  \
# NOC
# AUT  1924  Chamonix    Skating  Figure skating  AUT       individual
# AUT  1924  Chamonix    Skating  Figure skating  AUT       individual
# AUT  1924  Chamonix    Skating  Figure skating  AUT            pairs
# BEL  1924  Chamonix  Bobsleigh       Bobsleigh  BEL         four-man
# FIN  1924  Chamonix   Biathlon        Biathlon  FIN  military patrol
# FIN  1924  Chamonix    Skating  Figure skating  FIN            pairs
# FIN  1924  Chamonix    Skating   Speed skating  FIN           10000m
# FIN  1924  Chamonix    Skating   Speed skating  FIN           10000m
# FIN  1924  Chamonix    Skating   Speed skating  FIN            1500m
# FIN  1924  Chamonix    Skating   Speed skating  FIN            5000m
#
#     Event gender   Medal
# NOC
# AUT            M  Silver
# AUT            W    Gold
# AUT            X    Gold
# BEL            M  Bronze
# FIN            M  Silver
# FIN            X  Silver
# ...

# %%
data = pd.read_csv(url)
data.groupby('NOC').head(10)
# Out:
#       Year      City       Sport       Discipline  NOC            Event  \
# 0     1924  Chamonix     Skating   Figure skating  AUT       individual
# 1     1924  Chamonix     Skating   Figure skating  AUT       individual
# 2     1924  Chamonix     Skating   Figure skating  AUT            pairs
# 3     1924  Chamonix   Bobsleigh        Bobsleigh  BEL         four-man
# 4     1924  Chamonix  Ice Hockey       Ice Hockey  CAN       ice hockey
# ...    ...       ...         ...              ...  ...              ...
# 2231  2006     Turin    Biathlon         Biathlon  POL  15km mass start
# 2232  2006     Turin      Skiing  Cross Country S  POL             30km
# 2269  2006     Turin      Skiing        Snowboard  SVK  Snowboard Cross
# 2284  2006     Turin    Biathlon         Biathlon  UKR            7.5km
# 2285  2006     Turin     Skating   Figure skating  UKR      ice dancing
#
#      Event gender   Medal
# 0               M  Silver
# 1               W    Gold
# ...

# %%
data.groupby('NOC').count()
# Out:
#      Year  City  Sport  Discipline  Event  Event gender  Medal
# NOC
# AUS     6     6      6           6      6             6      6
# AUT   185   185    185         185    185           185    185
# BEL     5     5      5           5      5             5      5
# BLR     6     6      6           6      6             6      6
# BUL     6     6      6           6      6             6      6
# CAN   119   119    119         119    119           119    119
# CHN    33    33     33          33     33            33     33
# CRO     7     7      7           7      7             7      7
# CZE    10    10     10          10     10            10     10
# DEN     1     1      1           1      1             1      1
# ESP     2     2      2           2      2             2      2
# EST     6     6      6           6      6             6      6
# EUA    19    19     19          19     19            19     19
# EUN    23    23     23          23     23            23     23
# ...

# %%
data.groupby(['Year','NOC']).head()
# Out:
#       Year      City       Sport      Discipline  NOC        Event  \
# 0     1924  Chamonix     Skating  Figure skating  AUT   individual
# 1     1924  Chamonix     Skating  Figure skating  AUT   individual
# 2     1924  Chamonix     Skating  Figure skating  AUT        pairs
# 3     1924  Chamonix   Bobsleigh       Bobsleigh  BEL     four-man
# 4     1924  Chamonix  Ice Hockey      Ice Hockey  CAN   ice hockey
# ...    ...       ...         ...             ...  ...          ...
# 2286  2006     Turin   Bobsleigh       Bobsleigh  USA      two-man
# 2287  2006     Turin     Curling         Curling  USA      curling
# 2288  2006     Turin  Ice Hockey      Ice Hockey  USA   ice hockey
# 2289  2006     Turin     Skating  Figure skating  USA  ice dancing
# 2290  2006     Turin     Skating  Figure skating  USA   individual
#
#      Event gender   Medal
# 0               M  Silver
# 1               W    Gold
# 2               X    Gold
# 3               M  Bronze
# ...

# %%
data = pd.read_csv(url)

# %%
def uppercase(x):
  return x.upper()
data['Event'].apply(uppercase)[0:2311]
# Out:
# 0            INDIVIDUAL
# 1            INDIVIDUAL
# 2                 PAIRS
# 3              FOUR-MAN
# 4            ICE HOCKEY
#              ...
# 2306          HALF-PIPE
# 2307          HALF-PIPE
# 2308          HALF-PIPE
# 2309    SNOWBOARD CROSS
# 2310    SNOWBOARD CROSS
# Name: Event, Length: 2311, dtype: object

# %%
pip install scikit-fuzzy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 994.0/994.0 KB 10.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for scikit-fuzzy: filename=scikit_fuzzy-0.4.2-py3-none-any.whl size=894088 sha256=062c24be7767340814ac9d5c731c06f3faa1954447fbdb2963b34b40c45c6fe2
#   Stored in directory: /root/.cache/pip/wheels/2c/04/80/7eefb1a2de7d36aefd06432fab2a1486caf0a0596a7067391a
# Successfully built scikit-fuzzy
# ...

# %%
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt
x = np.arange(30,80.1,0.1)
slow = fuzz.trimf(x,[30,30,50])
medium = fuzz.trimf(x,[30,50,70])
fas = fuzz.trimf(x,[60,80,80])
full_speed = fuzz.trimf(x,[70,85,90])
plt.figure()
plt.plot(x,slow,'r',linewidth = 1.5 , label = 'slow')
plt.plot(x,medium,'b',linewidth = 1.5 , label = 'medium')
plt.plot(x,fas,'g',linewidth = 1.5 , label = 'fas')
plt.plot(x,full_speed,'y',linewidth = 1.5 , label = 'full_speed')

# %%
from skfuzzy.membership.generatemf import trapmf
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt
x = np.arange(30,80.1,0.1)
slow = fuzz.trapmf(x,[30,30,30,50])
medium = fuzz.trapmf(x,[30,50,50,70])
fas = fuzz.trapmf(x,[60,80,80,80])
full_speed = trapmf(x,[70,85,85,90])
plt.figure()
plt.plot(x,slow,'r',linewidth = 1.5 , label = 'slow')
plt.plot(x,medium,'b',linewidth = 1.5 , label = 'medium')
plt.plot(x,fas,'g',linewidth = 1.5 , label = 'fas')
plt.plot(x,full_speed,'y',linewidth = 1.5 , label = 'full_speed')

# %%
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt
x = np.arange(30,80.1,0.1)
slow = fuzz.gaussmf(x,30,4)
medium = fuzz.gaussmf(x,50,4)
fas = fuzz.gaussmf(x,80,4)
full_speed = fuzz.gaussmf(x,80,3)
plt.figure()
plt.plot(x,slow,'r',linewidth = 1.5 , label = 'slow')
plt.plot(x,medium,'b',linewidth = 1.5 , label = 'medium')
plt.plot(x,fas,'g',linewidth = 1.5 , label = 'fas')
plt.plot(x,full_speed,'y',linewidth = 1.5 , label = 'full_speed')

# %%
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt
x = np.arange(0,10.1,0.1)
do = fuzz.trimf(x,[0,0,5])
bt = fuzz.trimf(x,[0,5,10])
ngon = fuzz.trimf(x,[5,10,10])

plt.figure()
plt.plot(x,do,'r',linewidth = 1.5 , label = 'do')
plt.plot(x,bt,'b',linewidth = 1.5 , label = 'bt')
plt.plot(x,ngon,'g',linewidth = 1.5 , label = 'ngon')

# %%
from skfuzzy.control.controlsystem import ControlSystemSimulation
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt
from skfuzzy import control as ctrl
food = ctrl.Antecedent(np.arange(0,11,1),'food')
service = ctrl.Antecedent(np.arange(0,11,1),'service')
tip = ctrl.Consequent(np.arange(10,31,1),'tip')

food['poor']=fuzz.trimf(food.universe,[0,0,5])
food['average']=fuzz.trimf(food.universe,[0,5,10])
food['good']=fuzz.trimf(food.universe,[5,10,10])
service['poor']=fuzz.trimf(service.universe,[0,0,5])
service['average']=fuzz.trimf(service.universe,[0,5,10])
service['good']=fuzz.trimf(service.universe,[5,10,10])
tip['less']= fuzz.trimf(tip.universe,[10,10,20])
tip['average']= fuzz.trimf(tip.universe,[10,20,30])
tip['much']= fuzz.trimf(tip.universe,[20,30,30])

rule1=ctrl.Rule(food['poor'] & service['poor'],tip['less'])
rule2=ctrl.Rule(food['poor'] & service['average'],tip['less'])
rule3=ctrl.Rule(food['poor'] & service['good'],tip['average'])
rule4=ctrl.Rule(food['average'] & service['poor'],tip['less'])
rule5=ctrl.Rule(food['average'] & service['average'],tip['average'])
rule6=ctrl.Rule(food['average'] & service['good'],tip['much'])
rule7=ctrl.Rule(food['good'] & service['poor'],tip['average'])
rule8=ctrl.Rule(food['good'] & service['average'],tip['much'])
rule9=ctrl.Rule(food['good'] & service['good'],tip['much'])

tipping_ctrl = ctrl.ControlSystem([rule1,rule2,rule3,rule4,rule5,rule6,rule7,rule8,rule9])
tipping = ControlSystemSimulation(tipping_ctrl)
tipping.input['food']=8.0
tipping.input['service']=9.0
tipping.compute()
print(tipping.output['tip'])
tip.view(sim = tipping)
# Out:
# 22.967741935483872

# %%
from skfuzzy.control.controlsystem import ControlSystemSimulation
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt
from skfuzzy import control as ctrl
time= ctrl.Antecedent(np.arange(10,180,1),'Time')
rice = ctrl.Antecedent(np.arange(200,2000,1),'Rice')
pow = ctrl.Consequent(np.arange(0,100,0.1),'Pow')

time['ratngan']=fuzz.trimf(time.universe,[10,10,50])
time['ngan']=fuzz.trimf(time.universe,[40,60,100])
time['trungbinh']=fuzz.trimf(time.universe,[80,120,140])
time['khalau']=fuzz.trimf(time.universe,[130,155,180])
time['lau']=fuzz.trimf(time.universe,[180,180,180])
rice['it']=fuzz.trimf(rice.universe,[200,200,1000])
rice['vua']=fuzz.trimf(rice.universe,[200,1000,2000])
rice['nhieu']=fuzz.trimf(rice.universe,[1000,2000,2000])
pow['thap']=fuzz.trimf(pow.universe,[0,0,50])
pow['trungbinh']=fuzz.trimf(pow.universe,[0,50,100])
pow['cao']=fuzz.trimf(pow.universe,[50,100,100])

luat1 = ctrl.Rule(time['ratngan'] & rice['it'],pow['trungbinh'])
luat2 = ctrl.Rule(time['ratngan'] & rice['vua'],pow['cao'])
luat3 = ctrl.Rule(time['ratngan'] & rice['nhieu'],pow['cao'])
luat4 = ctrl.Rule(time['ngan'] & rice['it'],pow['thap'])
luat5 = ctrl.Rule(time['ngan'] & rice['vua'],pow['trungbinh'])
luat6 = ctrl.Rule(time['ngan'] & rice['nhieu'],pow['cao'])
luat7 = ctrl.Rule(time['trungbinh'] & rice['it'],pow['thap'])
luat8 = ctrl.Rule(time['trungbinh'] & rice['vua'],pow['thap'])
luat9 = ctrl.Rule(time['trungbinh'] & rice['nhieu'],pow['trungbinh'])
luat10 = ctrl.Rule(time['khalau'] & rice['it'],pow['thap'])
luat11 = ctrl.Rule(time['khalau'] & rice['vua'],pow['trungbinh'])
luat12 = ctrl.Rule(time['khalau'] & rice['nhieu'],pow['trungbinh'])
luat13 = ctrl.Rule(time['lau'] & rice['it'],pow['thap'])
luat14 = ctrl.Rule(time['lau'] & rice['vua'],pow['thap'])
luat15 = ctrl.Rule(time['lau'] & rice['nhieu'],pow['trungbinh'])

tipping_ctrl = ctrl.ControlSystem([luat1,luat2,luat3,luat4,luat5,luat6,luat7,luat8,luat9,luat10,luat11,luat12,luat13,luat14,luat15])
tipping = ControlSystemSimulation(tipping_ctrl)
tipping.input['Time']=100
tipping.input['Rice']=50
tipping.compute()
print(tipping.output['Pow'])
pow.view(sim = tipping)
# Out:
# 19.44444444444445
